# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("NetflixOriginals.csv",encoding="ISO-8859-1")#Verinin okutulması

# %%
data.head()
# Out:
#              Title                  Genre           Premiere  Runtime  \
# 0  Enter the Anime            Documentary     August 5, 2019       58
# 1      Dark Forces               Thriller    August 21, 2020       81
# 2          The App  Science fiction/Drama  December 26, 2019       79
# 3   The Open House        Horror thriller   January 19, 2018       94
# 4      Kaali Khuhi                Mystery   October 30, 2020       90
#
#    IMDB Score          Language
# 0         2.5  English/Japanese
# 1         2.6           Spanish
# 2         2.6           Italian
# 3         3.2           English
# 4         3.4             Hindi

# %% [markdown]
# # İngilizce çekilen filmler içerisinde hangi tür en yüksek IMDB puanına sahiptir?

# %%
ing = data[data['Language']=='English']#Dili ingilizce olan filmler
ing.head()
# Out:
#                               Title                    Genre  \
# 3                    The Open House          Horror thriller
# 7   The Last Days of American Crime      Heist film/Thriller
# 8                           Paradox  Musical/Western/Fantasy
# 10             Searching for Sheela              Documentary
# 14                            Mercy                 Thriller
#
#              Premiere  Runtime  IMDB Score Language
# 3    January 19, 2018       94         3.2  English
# 7        June 5, 2020      149         3.7  English
# 8      March 23, 2018       73         3.9  English
# 10     April 22, 2021       58         4.1  English
# 14  November 22, 2016       90         4.2  English

# %%
best= ing.nlargest(15,'IMDB Score')
best
# Out:
#                                             Title  \
# 583      David Attenborough: A Life on Our Planet
# 581                       Springsteen on Broadway
# 578    Ben Platt: Live from Radio City Music Hall
# 579         Taylor Swift: Reputation Stadium Tour
# 576                       Cuba and the Cameraman
# 577                        Dancing with the Birds
# 571                                          13th
# 572             Disclosure: Trans Lives on Screen
# 573                                         Klaus
# 574                                    Seaspiracy
# 568                                Chasing Coral
# 569                            My Octopus Teacher
# 570                                Rising Phoenix
# 567  Struggle: The Life and Lost Art of Szukaiski
# 563                                 A Secret Love
#
#                                     Genre           Premiere  Runtime  \
# 583                           Documentary    October 4, 2020       83
# ...

# %%
best= ing.nlargest(1,'IMDB Score')#İngilizce çekilen filmler içerisinde en yüksek IMDB puanına sahip olan tür
print(best['Genre'])
# Out:
# 583    Documentary
# Name: Genre, dtype: object

# %% [markdown]
# # 'Hindi' Dilinde çekilmiş olan filmlerin ortalama 'runtime' suresi nedir?

# %%
hind = data[data['Language']=='Hindi']#Dili hindi olan filmler
hind.head()
# Out:
#                     Title             Genre           Premiere  Runtime  \
# 4             Kaali Khuhi           Mystery   October 30, 2020       90
# 5                   Drive            Action   November 1, 2019      147
# 9      Sardar Ka Grandson            Comedy       May 18, 2021      139
# 16          Ghost Stories  Horror anthology    January 1, 2020      144
# 23  The Girl on the Train          Thriller  February 26, 2021      120
#
#     IMDB Score Language
# 4          3.4    Hindi
# 5          3.5    Hindi
# 9          4.1    Hindi
# 16         4.3    Hindi
# 23         4.4    Hindi

# %%
ort=hind['Runtime'].mean()#'Hindi' Dilinde çekilmiş olan filmlerin ortalama 'runtime' suresi 
ort
# Out:
# 115.78787878787878
